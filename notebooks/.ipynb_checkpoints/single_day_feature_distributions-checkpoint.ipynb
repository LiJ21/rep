# %% [markdown]
# # Single-Day LOB Feature Distributions
#
# Build one day of L2/order-book features from raw MBO, add future as-of price labels, then plot distributions and QQ plots.

# %%
from __future__ import annotations

import sys
from pathlib import Path
from statistics import NormalDist

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import matplotlib.pyplot as plt
import numpy as np
import polars as pl

from tools.data import FeatureLoader, RAW_PATH
from tools.features import LOBFeatures, depth_meta
from tools.price import add_executable_return, add_return

# %%
# Data
DAY = "2026-05-05"
PROD = "ES"
L2_DEPTH = 5
BATCH_SIZE = 65_536
REQUIRE_VALID_TOP = True

# Feature knobs
IMBALANCE_DEPTHS = [1, 3, 5]
IMBALANCE_LOG = False
WEIGHTED_PRICE_DEPTH = 5
WEIGHTED_PRICE_SIZES = [10, 25, 50]
TRADE_MOMENTUM_HALF_LIVES = ['1s', '10s', '1m']

# Future label knobs
FUTURE_HORIZONS = ["1s", "5s", "15s"]
FUTURE_WEIGHTS = [0.5, 0.3, 0.2]
EXECUTABLE_SIZE = 25
EXECUTABLE_DEPTH = 5

# Plot knobs
PLOT_COLUMNS = None  # or set an explicit list[str]
PLOT_SAMPLE_N = 200_000
QQ_SAMPLE_N = 20_000
RNG_SEED = 7

assert L2_DEPTH >= max([*IMBALANCE_DEPTHS, WEIGHTED_PRICE_DEPTH, EXECUTABLE_DEPTH])

# %%
def raw_path(day: str, prod: str) -> Path:
    path = Path(
        RAW_PATH.format(
            prod=prod,
            prod_s=prod.lower(),
            d=day,
            dnd=day.replace("-", ""),
            dslash=day.replace("-", "/"),
            tag="*",
        )
    )
    matches = sorted(path.parent.glob(path.name))
    if len(matches) != 1:
        raise ValueError(f"expected one file for {day=} {prod=}, matched {matches}")
    return matches[0]


def tag(x: object) -> str:
    return str(x).replace(".", "p")


def feature_exprs() -> dict[str, pl.Expr]:
    exprs = {}
    for depth in IMBALANCE_DEPTHS:
        exprs[f"imb_d{depth}"] = LOBFeatures.book_imbalance(depth, log=IMBALANCE_LOG)
    for size in sorted(set([*WEIGHTED_PRICE_SIZES, EXECUTABLE_SIZE])):
        exprs[f"weighted_price_sz{tag(size)}"] = LOBFeatures.size_weighted_avg_price(WEIGHTED_PRICE_DEPTH, size)
    return exprs


def stateful_features() -> tuple[LOBFeatures.TradeMomentum, ...]:
    return tuple(
        LOBFeatures.TradeMomentum(
            f"trade_momentum_hl{tag(half_life)}",
            half_life,
        )
        for half_life in TRADE_MOMENTUM_HALF_LIVES
    )


path = raw_path(DAY, PROD)
exprs = feature_exprs()
stateful = stateful_features()
features = [*exprs, *[feature.name for feature in stateful]]
current_exec_col = f"weighted_price_sz{tag(EXECUTABLE_SIZE)}"
path
# Out:
# PosixPath('/home/jli/projects/rep/data/databento_glbx_mdp3_mbo_full_day_parquet/ESM6_2026-05-05_normal_es_full_day.parquet')

# %%
meta_cols = ["ts_event", "ts_recv", "symbol", *depth_meta(L2_DEPTH)]
loader = FeatureLoader(
    prod=PROD,
    feature_exprs=exprs,
    stateful_features=stateful,
    l2_depth=L2_DEPTH,
    path=RAW_PATH,
    meta_cols=meta_cols,
    batch_size=BATCH_SIZE,
)
df = loader.load_date(DAY, PROD).lf.collect(engine="streaming")
if REQUIRE_VALID_TOP:
    df = df.filter((pl.col("bid_px_0") != 9_223_372_036_854_775_807) & (pl.col("ask_px_0") != 9_223_372_036_854_775_807))
df = df.sort(["publisher_id", "instrument_id", "ts_event", "row_nr"])
df = df.with_columns(((pl.col("bid_px_0") + pl.col("ask_px_0")) / 2).alias("mid"))
df.head(20)
# Out:
# shape: (20, 50)
# ┌────────────┬────────────┬────────┬────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ ts_event   ┆ ts_recv    ┆ symbol ┆ row_nr ┆ … ┆ trade_mome ┆ trade_mome ┆ trade_mome ┆ mid       │
# │ ---        ┆ ---        ┆ ---    ┆ ---    ┆   ┆ ntum_hl1s  ┆ ntum_hl10s ┆ ntum_hl1m  ┆ ---       │
# │ datetime[n ┆ datetime[n ┆ str    ┆ u64    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ f64       │
# │ s, UTC]    ┆ s, UTC]    ┆        ┆        ┆   ┆ f64        ┆ f64        ┆ f64        ┆           │
# ╞════════════╪════════════╪════════╪════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ 2026-05-03 ┆ 2026-05-05 ┆ ESM6   ┆ 1540   ┆ … ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ 7.2406e12 │
# │ 12:00:05.5 ┆ 00:00:00   ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 37292457 … ┆ UTC        ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 2026-05-03 ┆ 2026-05-05 ┆ ESM6   ┆ 1541   ┆ … ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ 7.2406e12 │
# │ 12:00:05.5 ┆ 00:00:00   ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 37292457 … ┆ UTC        ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 2026-05-03 ┆ 2026-05-05 ┆ ESM6   ┆ 1542   ┆ … ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ 7.2406e12 │
# │ 12:00:05.5 ┆ 00:00:00   ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 37292457 … ┆ UTC        ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 2026-05-03 ┆ 2026-05-05 ┆ ESM6   ┆ 1543   ┆ … ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ 7.2406e12 │
# │ 12:00:05.5 ┆ 00:00:00   ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 37292457 … ┆ UTC        ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 2026-05-03 ┆ 2026-05-05 ┆ ESM6   ┆ 1544   ┆ … ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ 7.2406e12 │
# │ 12:00:05.5 ┆ 00:00:00   ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 37292457 … ┆ UTC        ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ …          ┆ …          ┆ …      ┆ …      ┆ … ┆ …          ┆ …          ┆ …          ┆ …         │
# │ 2026-05-03 ┆ 2026-05-05 ┆ ESM6   ┆ 1764   ┆ … ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ 7.2396e12 │
# │ 22:00:00.1 ┆ 00:00:00   ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 18287945 … ┆ UTC        ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 2026-05-03 ┆ 2026-05-05 ┆ ESM6   ┆ 1765   ┆ … ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ 7.2396e12 │
# │ 22:00:00.1 ┆ 00:00:00   ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 18317783 … ┆ UTC        ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 2026-05-03 ┆ 2026-05-05 ┆ ESM6   ┆ 1775   ┆ … ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ 7.2396e12 │
# │ 22:00:00.1 ┆ 00:00:00   ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 92510243 … ┆ UTC        ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 2026-05-03 ┆ 2026-05-05 ┆ ESM6   ┆ 1776   ┆ … ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ 7.2396e12 │
# │ 22:00:00.1 ┆ 00:00:00   ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 92567457 … ┆ UTC        ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 2026-05-03 ┆ 2026-05-05 ┆ ESM6   ┆ 1971   ┆ … ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ 7.2396e12 │
# │ 22:00:06.0 ┆ 00:00:00   ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# │ 77763395 … ┆ UTC        ┆        ┆        ┆   ┆            ┆            ┆            ┆           │
# └────────────┴────────────┴────────┴────────┴───┴────────────┴────────────┴────────────┴───────────┘

# %%
df = add_return(
    df,
    pl.col("mid"),
    FUTURE_HORIZONS,
    FUTURE_WEIGHTS,
    name="future_mid",
)
df = add_executable_return(
    df,
    EXECUTABLE_DEPTH,
    EXECUTABLE_SIZE,
    FUTURE_HORIZONS,
    FUTURE_WEIGHTS,
    name="future_executable_price",
)
df = df.with_columns(
    (pl.col("future_mid") - pl.col("mid")).alias("future_mid_change"),
    (pl.col("future_executable_price") - pl.col(current_exec_col)).alias("future_executable_change"),
)

summary_cols = [*features, "mid", "future_mid", "future_executable_price", "future_mid_change", "future_executable_change"]
df.select(summary_cols).describe()
# Out:
# shape: (9, 15)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ imb_d1    ┆ imb_d3    ┆ imb_d5    ┆ … ┆ future_mi ┆ future_ex ┆ future_mi ┆ future_e │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ d         ┆ ecutable_ ┆ d_change  ┆ xecutabl │
# │ str       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ ---       ┆ price     ┆ ---       ┆ e_change │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ ---       ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 7.127647e ┆ 7.127647e ┆ 7.127647e ┆ … ┆ 7.127356e ┆ 7.127356e ┆ 7.127356e ┆ 7.127356 │
# │           ┆ 6         ┆ 6         ┆ 6         ┆   ┆ 6         ┆ 6         ┆ 6         ┆ e6       │
# │ null_coun ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ … ┆ 291.0     ┆ 291.0     ┆ 291.0     ┆ 291.0    │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ -0.436898 ┆ -1.170674 ┆ -1.712763 ┆ … ┆ 0.011627  ┆ NaN       ┆ -7.2763e1 ┆ NaN      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 2         ┆          │
# │ std       ┆ 43.260985 ┆ 46.345376 ┆ 46.791369 ┆ … ┆ 0.583648  ┆ NaN       ┆ 1.7349e10 ┆ NaN      │
# │ min       ┆ -915.0    ┆ -907.8    ┆ -908.1174 ┆ … ┆ -14.88248 ┆ -inf      ┆ -7.3199e1 ┆ -inf     │
# │           ┆           ┆           ┆ 6         ┆   ┆           ┆           ┆ 2         ┆          │
# │ 25%       ┆ -23.0     ┆ -25.13333 ┆ -25.94920 ┆ … ┆ -0.205956 ┆ -13428.65 ┆ -7.2866e1 ┆ -13428.6 │
# │           ┆           ┆ 3         ┆ 6         ┆   ┆           ┆ 3816      ┆ 2         ┆ 51519    │
# │ 50%       ┆ 0.0       ┆ -0.333333 ┆ -0.565079 ┆ … ┆ 0.0       ┆ -9364.663 ┆ -7.2799e1 ┆ -9364.76 │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 84        ┆ 2         ┆ 4563     │
# │ 75%       ┆ 22.0      ┆ 23.4      ┆ 23.283333 ┆ … ┆ 0.240075  ┆ 1300.2731 ┆ -7.2694e1 ┆ 1300.250 │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 29        ┆ 2         ┆ 321      │
# │ max       ┆ 600.0     ┆ 588.86666 ┆ 591.04127 ┆ … ┆ 20.445556 ┆ inf       ┆ -7.2196e1 ┆ inf      │
# │           ┆           ┆ 7         ┆           ┆   ┆           ┆           ┆ 2         ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# df.select(2 * (pl.col('ask_px_0') - pl.col('bid_px_0')) / (pl.col('ask_px_0') + pl.col('bid_px_0')) * 1e4).describe()
df.select((pl.col('ask_px_0') - pl.col('bid_px_0'))).describe()
# Out:
# shape: (9, 2)
# ┌────────────┬────────────┐
# │ statistic  ┆ ask_px_0   │
# │ ---        ┆ ---        │
# │ str        ┆ f64        │
# ╞════════════╪════════════╡
# │ count      ┆ 7.127647e6 │
# │ null_count ┆ 0.0        │
# │ mean       ┆ 2.7184e8   │
# │ std        ┆ 5.0558e8   │
# │ min        ┆ -2.6500e10 │
# │ 25%        ┆ 2.5e8      │
# │ 50%        ┆ 2.5e8      │
# │ 75%        ┆ 2.5e8      │
# │ max        ┆ 8.2750e10  │
# └────────────┴────────────┘

# %%
def finite_values(frame: pl.DataFrame, col: str, sample_n: int, seed: int) -> np.ndarray:
    x = frame.get_column(col).drop_nulls().to_numpy()
    x = x[np.isfinite(x)]
    if len(x) > sample_n:
        rng = np.random.default_rng(seed)
        x = rng.choice(x, sample_n, replace=False)
    return x


def plot_distribution_qq(frame: pl.DataFrame, cols: list[str]) -> None:
    normal = NormalDist()
    fig, axes = plt.subplots(len(cols), 2, figsize=(12, 3.2 * len(cols)))
    axes = np.atleast_2d(axes)

    for i, col in enumerate(cols):
        x = finite_values(frame, col, PLOT_SAMPLE_N, RNG_SEED + i)
        axes[i, 0].hist(x, bins=100, density=True, alpha=0.8)
        axes[i, 0].set_title(f"{col} distribution")

        q = finite_values(frame, col, QQ_SAMPLE_N, RNG_SEED + 10_000 + i)
        q = q[np.isfinite(q)]
        if len(q) > 1 and q.std() > 0:
            z = np.sort((q - q.mean()) / q.std())
            p = (np.arange(1, len(z) + 1) - 0.5) / len(z)
            theory = np.array([normal.inv_cdf(float(v)) for v in p])
            axes[i, 1].scatter(theory, z, s=3, alpha=0.35)
            lo, hi = min(theory[0], z[0]), max(theory[-1], z[-1])
            axes[i, 1].plot([lo, hi], [lo, hi], color="black", linewidth=1)
        axes[i, 1].set_title(f"{col} QQ vs normal")

    fig.suptitle(f"{PROD} {DAY}", y=1.0)
    fig.tight_layout()
    plt.show()

# %%
plot_cols = PLOT_COLUMNS or [
    *exprs.keys(),
    "future_mid_change",
    "future_executable_change",
]
plot_cols = [c for c in plot_cols if c in df.columns]
plot_distribution_qq(df, plot_cols)
